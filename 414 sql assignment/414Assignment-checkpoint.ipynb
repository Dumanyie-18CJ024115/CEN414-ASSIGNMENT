# %%
import pyodbc
import pandas


conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DESKTOP-GOM4RUN;'
                      'Database=CEN_ASSIGNMENT;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
cursor.execute('SELECT * FROM dbo.chamberlain')

for i in cursor:
    print(i)
# Out:
# ('Algeria', 'DZA', '105', '105', '105', '105', '105', '105', '102.6', '105', '105', '105')
# ('Angola', 'AGO', '102', '102.8', '103', '103', '103', '103', '104.1', '103', '103', '103')
# ('Benin', 'BEN', '104', '104.1', '104.1', '104.1', '104.1', '104.1', '103.1', '104.1', '104.1', '104.1')
# ('Botswana', 'BWA', '103', '103.1', '103.1', '103.1', '103.1', '103.1', '104.6', '103.1', '103.1', '103.1')
# ('Burkina Faso', 'BFA', '104', '103', '104.6', '104.6', '104.6', '104.6', '103', '104.6', '104.6', '104.6')
# ('Burundi', 'BDI', '103', '103', '103', '103', '103', '103', '103', '103', '103', '103')
# ('Cameroon', 'CMR', '103', '103', '103', '103', '103', '103', '103', '103', '103', '103')
# ('Cape Verde', 'CPV', '103', '103', '103', '103', '103', '103', '103', '103', '103', '103')
# ('Central African Republic', 'CAF', '103', '103', '103', '103', '103', '103', '103', '103', '103', '103')
# ('Chad', 'TCD', '103', '103', '103', '103', '103', '103', '105', '103', '103', '103')
# ...

# %%
import pyodbc
import pandas as pd
server = 'DESKTOP-GOM4RUN' 
database = 'CEN_ASSIGNMENT' 
username = 'DESKTOP-GOM4RUN\Chamberlain' 
password = 'CEN_ASSIGNMEENT'  
conn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+'; Trusted_Connection=yes;')
cursor = conn.cursor()
query = "SELECT * FROM dbo.chamberlain;"
df = pd.read_sql(query, conn)
df
# Out:
#                          Country Code Sex_ratio_at_birth_2010  \
# 0                        Algeria  DZA                     105
# 1                         Angola  AGO                     102
# 2                          Benin  BEN                     104
# 3                       Botswana  BWA                     103
# 4                   Burkina Faso  BFA                     104
# 5                        Burundi  BDI                     103
# 6                       Cameroon  CMR                     103
# 7                     Cape Verde  CPV                     103
# 8       Central African Republic  CAF                     103
# 9                           Chad  TCD                     103
# 10                       Comoros  COM                     105
# 11                         Congo  COG                     103
# 12                 Cote d Ivoire  CIV                     103
# 13  Democratic Republic of Congo  COD                     103
# ...
